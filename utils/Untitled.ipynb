# %%
from CVRP import CVRP
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
teste = CVRP('teste.vrp')

# %%
c = ['blue' if i != 0 else 'red' for i in range(len(teste.demand))]
plt.scatter(teste.coord[:,0],teste.coord[:,1], c = c)

# %%
teste.dist[0]
# Out:
# array([ 0.        , 15.23154621, 18.        , 22.36067977, 25.        ,
#        20.61552813, 11.18033989, 21.21320344, 26.2488095 , 32.01562119,
#        25.49509757, 33.54101966, 15.        , 11.18033989, 32.01562119,
#        30.41381265, 29.15475947, 30.41381265, 15.8113883 , 32.01562119,
#        31.6227766 , 18.02775638, 26.92582404, 36.05551275, 30.        ,
#        33.54101966, 11.18033989,  5.        ,  6.32455532, 29.83286778,
#        25.49509757, 17.4642492 , 34.        , 24.75883681, 36.05551275,
#        41.03656906, 41.40048309, 21.21320344, 42.42640687, 33.9705755 ,
#        11.18033989, 28.86173938, 25.49509757, 34.17601498, 31.89043744,
#        29.15475947, 35.4682957 , 34.20526275, 27.80287755, 43.93176527,
#        16.97056275, 26.92582404, 11.3137085 ,  4.47213595, 22.8035085 ,
#        30.46309242, 29.20616373, 23.19482701,  9.05538514, 17.80449381,
#        18.02775638, 25.49509757, 25.49509757, 34.92849839, 46.5188134 ,
# ...

# %%
teste.dist[1]
# Out:
# array([15.23154621,  0.        , 32.55764119, 14.56021978, 32.20248438,
#        32.20248438, 24.8394847 , 21.02379604, 31.57530681, 17.80449381,
#        15.55634919, 26.40075756, 16.64331698, 26.40075756, 46.87216658,
#        45.35416188, 42.44997055, 40.70626487, 22.84731932, 28.23118843,
#        16.4924225 , 29.27456234, 39.20459157, 46.17358552, 27.78488798,
#        37.64306045, 19.41648784, 10.81665383, 12.        , 24.04163056,
#        11.04536102, 10.44030651, 20.88061302, 12.36931688, 24.73863375,
#        27.20294102, 40.52159918, 35.80502758, 56.85068161, 41.59326869,
#        24.0208243 , 42.01190308, 40.71854614, 49.39635614, 46.09772229,
#        36.68787266, 39.01281841, 33.73425559, 28.16025568, 39.8246155 ,
#         6.32455532, 12.04159458, 15.23154621, 18.43908891, 25.61249695,
#        34.05877273, 38.89730068, 38.07886553, 23.53720459, 32.01562119,
#        28.3019434 , 38.28837944, 19.23538406, 24.41311123, 38.20994635,
# ...

# %%
import numpy as np

# %%
np.linalg.norm(x = teste[:,0], y = )

# %%
from scipy.spatial.distance import euclidean

# %%
euclidean(teste.coord[0], teste.coord[1])

# %%
a = np.zeros([teste.dimmension,teste.dimmension])
for i in range(teste.dimmension):
    for j in range(i):
        d = distance.euclidean(teste.coord[i], teste.coord[j])
        a[i][j] = d
        a[j][i] = d

print(a[1])
